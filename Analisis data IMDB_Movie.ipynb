# %%
import pandas as pd

# %%
#import dataset
dataset = pd.read_csv('imdb_top_1000.csv')

# %%
dataset.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
dataset.shape
# Out:
# (1000, 16)

# %%
dataset.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
dataset.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
dataset['Certificate'].unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
dataset.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df = dataset.dropna()
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.isnull().sum()
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 997
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    object
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 94.8+ KB

# %% [markdown]
# 1. Cek data apakah terdapat duplicate data?

# %% [markdown]
# duplicate()

# %%
df.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.shape
# Out:
# (714, 16)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %% [markdown]
# 2. Cek missing value dengan heatmap

# %%
df.isnull()
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0          False         False          False        False    False  False
# 1          False         False          False        False    False  False
# 2          False         False          False        False    False  False
# 3          False         False          False        False    False  False
# 4          False         False          False        False    False  False
# ..           ...           ...            ...          ...      ...    ...
# 990        False         False          False        False    False  False
# 991        False         False          False        False    False  False
# 992        False         False          False        False    False  False
# 994        False         False          False        False    False  False
# 997        False         False          False        False    False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %% [markdown]
# Seaborn Library (Heatmap)

# %%
import seaborn as sns

# %%
sns.heatmap(dataset.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Q.1 Tahun berapa sajakah Series yang berjudul ''Dirsyam' Released?

# %%
dataset.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
dataset['Series_Title'].value_counts()
# Out:
# Drishyam                     2
# Kill Bill: Vol. 2            1
# The Lion in Winter           1
# Anand                        1
# District 9                   1
#                             ..
# In the Name of the Father    1
# Dom za vesanje               1
# Salinui chueok               1
# Ace in the Hole              1
# Coraline                     1
# Name: Series_Title, Length: 999, dtype: int64

# %% [markdown]
# isin()

# %%
dataset[dataset['Series_Title'].isin(['Drishyam'])]
# Out:
#                                            Poster_Link Series_Title  \
# 87   https://m.media-amazon.com/images/M/MV5BYmY3Mz...     Drishyam
# 136  https://m.media-amazon.com/images/M/MV5BYmJhZm...     Drishyam
#
#     Released_Year Certificate  Runtime                   Genre  IMDB_Rating  \
# 87           2013           U  160 min  Crime, Drama, Thriller          8.3
# 136          2015          UA  163 min   Crime, Drama, Mystery          8.2
#
#                                               Overview  Meta_score  \
# 87   A man goes to extreme lengths to save his fami...         NaN
# 136  Desperate measures are taken by a man who trie...         NaN
#
#             Director       Star1         Star2         Star3         Star4  \
# 87     Jeethu Joseph    Mohanlal         Meena  Asha Sharath        Ansiba
# 136  Nishikant Kamat  Ajay Devgn  Shriya Saran          Tabu  Rajat Kapoor
#
#      No_of_Votes    Gross
# 87         30722      NaN
# 136        70367  739,478

# %% [markdown]
# str.contains()

# %%
dataset[dataset['Series_Title'].str.contains('Drishyam')]
# Out:
#                                            Poster_Link Series_Title  \
# 87   https://m.media-amazon.com/images/M/MV5BYmY3Mz...     Drishyam
# 136  https://m.media-amazon.com/images/M/MV5BYmJhZm...     Drishyam
#
#     Released_Year Certificate  Runtime                   Genre  IMDB_Rating  \
# 87           2013           U  160 min  Crime, Drama, Thriller          8.3
# 136          2015          UA  163 min   Crime, Drama, Mystery          8.2
#
#                                               Overview  Meta_score  \
# 87   A man goes to extreme lengths to save his fami...         NaN
# 136  Desperate measures are taken by a man who trie...         NaN
#
#             Director       Star1         Star2         Star3         Star4  \
# 87     Jeethu Joseph    Mohanlal         Meena  Asha Sharath        Ansiba
# 136  Nishikant Kamat  Ajay Devgn  Shriya Saran          Tabu  Rajat Kapoor
#
#      No_of_Votes    Gross
# 87         30722      NaN
# 136        70367  739,478

# %% [markdown]
# Q.2 Pada tahun berapakah Series terbanyak yang released?

# %%
dataset['Released_Year'].value_counts()
# Out:
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1922     1
# 1936     1
# 1926     1
# PG       1
# 1921     1
# Name: Released_Year, Length: 100, dtype: int64

# %% [markdown]
# Q.3 Berapa banyak Series berdasarkan Certificate?

# %% [markdown]
# Groupby()

# %%
dataset.head(3)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
#                Director           Star1           Star2          Star3  \
# ...

# %%
dataset.groupby('Certificate')['Certificate'].count()
# Out:
# Certificate
# 16            1
# A           197
# Approved     11
# G            12
# GP            2
# PG           37
# PG-13        43
# Passed       34
# R           146
# TV-14         1
# TV-MA         1
# TV-PG         3
# U           234
# U/A           1
# UA          175
# Unrated       1
# Name: Certificate, dtype: int64

# %% [markdown]
# countplot()

# %%
sns.countplot(dataset['Certificate']);
# Out:
# C:\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Q.4 Tunjukan Series yang released pada tahun 2014 dengan IMDB_Rating lebih dari 8?

# %% [markdown]
# Filtering

# %%
dataset[dataset['Released_Year']=='2014']
# Out:
#                                            Poster_Link  \
# 21   https://m.media-amazon.com/images/M/MV5BZjdkOT...
# 34   https://m.media-amazon.com/images/M/MV5BOTA5ND...
# 200  https://m.media-amazon.com/images/M/MV5BMGI3YW...
# 201  https://m.media-amazon.com/images/M/MV5BMjA1NT...
# 204  https://m.media-amazon.com/images/M/MV5BNGQzY2...
# 206  https://m.media-amazon.com/images/M/MV5BYzE2Mj...
# 207  https://m.media-amazon.com/images/M/MV5BMTYzOT...
# 209  https://m.media-amazon.com/images/M/MV5BMzM5Nj...
# 210  https://m.media-amazon.com/images/M/MV5BMTk0MD...
# 219  https://m.media-amazon.com/images/M/MV5BMTQ2MD...
# 337  https://m.media-amazon.com/images/M/MV5BMTg5MT...
# 338  https://m.media-amazon.com/images/M/MV5BOTgwMz...
# 339  https://m.media-amazon.com/images/M/MV5BMTAwMj...
# 372  https://m.media-amazon.com/images/M/MV5BMjE0ND...
# 474  https://m.media-amazon.com/images/M/MV5BN2U1Yz...
# 479  https://m.media-amazon.com/images/M/MV5BZGIzNW...
# ...

# %%
dataset[(dataset['Released_Year']=='2014')&(dataset['IMDB_Rating']>8)]
# Out:
#                                            Poster_Link  \
# 21   https://m.media-amazon.com/images/M/MV5BZjdkOT...
# 34   https://m.media-amazon.com/images/M/MV5BOTA5ND...
# 200  https://m.media-amazon.com/images/M/MV5BMGI3YW...
# 201  https://m.media-amazon.com/images/M/MV5BMjA1NT...
# 204  https://m.media-amazon.com/images/M/MV5BNGQzY2...
# 206  https://m.media-amazon.com/images/M/MV5BYzE2Mj...
# 207  https://m.media-amazon.com/images/M/MV5BMTYzOT...
# 209  https://m.media-amazon.com/images/M/MV5BMzM5Nj...
# 210  https://m.media-amazon.com/images/M/MV5BMTk0MD...
# 219  https://m.media-amazon.com/images/M/MV5BMTQ2MD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 21               Interstellar          2014          UA  169 min
# 34                   Whiplash          2014           A  106 min
# 200                     Mommy          2014           R  139 min
# 201                    Haider          2014          UA  160 min
# ...

# %% [markdown]
# Q.5 Tunjukan Series yang bergenre 'Comedy' dengan rating > 8?

# %%
dataset[(dataset['Genre'].str.contains('Comedy'))& (dataset['IMDB_Rating']>8)]
# Out:
#                                            Poster_Link  \
# 19   https://m.media-amazon.com/images/M/MV5BYWZjMj...
# 26   https://m.media-amazon.com/images/M/MV5BYmJmM2...
# 35   https://m.media-amazon.com/images/M/MV5BMTYxND...
# 47   https://m.media-amazon.com/images/M/MV5BZmU0M2...
# 51   https://m.media-amazon.com/images/M/MV5BYjJiZj...
# ..                                                 ...
# 311  https://m.media-amazon.com/images/M/MV5BNzc1MT...
# 313  https://m.media-amazon.com/images/M/MV5BZTYwYj...
# 316  https://m.media-amazon.com/images/M/MV5BYzJmMW...
# 318  https://m.media-amazon.com/images/M/MV5BM2QwYW...
# 320  https://m.media-amazon.com/images/M/MV5BYmRiMD...
#
#                      Series_Title Released_Year Certificate  Runtime  \
# 19                   Gisaengchung          2019           A  132 min
# 26                La vita è bella          1997           U  116 min
# 35               The Intouchables          2011          UA  112 min
# ...

# %% [markdown]
# Q.6 Tunjukan 10 director dengan series terbanyak?

# %%
dataset['Director'].value_counts().head(10)
# Out:
# Alfred Hitchcock     14
# Steven Spielberg     13
# Hayao Miyazaki       11
# Akira Kurosawa       10
# Martin Scorsese      10
# Woody Allen           9
# Billy Wilder          9
# Stanley Kubrick       9
# David Fincher         8
# Quentin Tarantino     8
# Name: Director, dtype: int64

# %% [markdown]
# Q.7 berapa banyak Charles Chaplin bermain dalam series sebagai bintang utama?

# %%
dataset[dataset['Star1']=='Charles Chaplin']
# Out:
#                                            Poster_Link        Series_Title  \
# 51   https://m.media-amazon.com/images/M/MV5BYjJiZj...        Modern Times
# 52   https://m.media-amazon.com/images/M/MV5BY2I4Mm...         City Lights
# 83   https://m.media-amazon.com/images/M/MV5BMmExYW...  The Great Dictator
# 127  https://m.media-amazon.com/images/M/MV5BZjhhMT...             The Kid
# 193  https://m.media-amazon.com/images/M/MV5BZjEyOT...       The Gold Rush
# 318  https://m.media-amazon.com/images/M/MV5BM2QwYW...          The Circus
#
#     Released_Year Certificate  Runtime                     Genre  IMDB_Rating  \
# 51           1936           G   87 min     Comedy, Drama, Family          8.5
# 52           1931           G   87 min    Comedy, Drama, Romance          8.5
# 83           1940      Passed  125 min        Comedy, Drama, War          8.4
# 127          1921      Passed   68 min     Comedy, Drama, Family          8.3
# ...

# %% [markdown]
# Q.8 Sebutkan 10 series yang memiliki vote tertinggi?

# %%
dataset.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
dataset.sort_values(by='No_of_Votes',ascending=False).head(10)
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 14  https://m.media-amazon.com/images/M/MV5BNzQzOT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 2                                     The Dark Knight          2008
# 8                                           Inception          2010
# 9                                          Fight Club          1999
# ...

# %% [markdown]
# Q.10 Runtime maksimum series ?

# %%
dataset.head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# ...

# %%
dataset['Runtime'].unique()
# Out:
# array(['142 min', '175 min', '152 min', '202 min', '96 min', '201 min',
#        '154 min', '195 min', '148 min', '139 min', '178 min', '161 min',
#        '179 min', '136 min', '146 min', '124 min', '133 min', '160 min',
#        '132 min', '153 min', '169 min', '130 min', '125 min', '189 min',
#        '116 min', '127 min', '118 min', '121 min', '207 min', '122 min',
#        '106 min', '112 min', '151 min', '150 min', '155 min', '119 min',
#        '110 min', '88 min', '137 min', '89 min', '165 min', '109 min',
#        '102 min', '87 min', '126 min', '147 min', '117 min', '181 min',
#        '149 min', '105 min', '164 min', '170 min', '98 min', '101 min',
#        '113 min', '134 min', '229 min', '115 min', '143 min', '95 min',
#        '104 min', '123 min', '131 min', '108 min', '81 min', '99 min',
#        '114 min', '129 min', '228 min', '128 min', '103 min', '107 min',
#        '68 min', '138 min', '156 min', '167 min', '163 min', '186 min',
# ...

# %%
dataset['Runtime'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# str.split()

# %%
dataset[['Minute','Unit']] = dataset['Runtime'].str.split(' ',expand=True)

# %%
dataset.head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes        Gross Minute Unit
# 0  William Sadler      2343110   28,341,469    142  min
# ...

# %%
dataset.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# Minute            object
# Unit              object
# dtype: object

# %%
dataset['Minute'].astype('int64').max()
# Out:
# 321

# %% [markdown]
# Q.11 Urutkan dataset berdasarkan tahun release

# %%
dataset.head(2)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                Series_Title Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption          1994           A  142 min         Drama
# 1             The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1           Star2       Star3  \
# 0        Frank Darabont    Tim Robbins  Morgan Freeman  Bob Gunton
# 1  Francis Ford Coppola  Marlon Brando       Al Pacino  James Caan
#
#             Star4  No_of_Votes        Gross Minute Unit
# 0  William Sadler      2343110   28,341,469    142  min
# ...

# %%
dataset.sort_values(by='Released_Year')
# Out:
#                                            Poster_Link  \
# 321  https://m.media-amazon.com/images/M/MV5BNWJiNG...
# 127  https://m.media-amazon.com/images/M/MV5BZjhhMT...
# 568  https://m.media-amazon.com/images/M/MV5BMTAxYj...
# 194  https://m.media-amazon.com/images/M/MV5BZWFhOG...
# 193  https://m.media-amazon.com/images/M/MV5BZjEyOT...
# ..                                                 ...
# 464  https://m.media-amazon.com/images/M/MV5BNmI0MT...
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 613  https://m.media-amazon.com/images/M/MV5BOTNjM2...
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...
#
#                      Series_Title Released_Year Certificate  Runtime  \
# 321  Das Cabinet des Dr. Caligari          1920         NaN   76 min
# 127                       The Kid          1921      Passed   68 min
# 568                     Nosferatu          1922         NaN   94 min
# ...
